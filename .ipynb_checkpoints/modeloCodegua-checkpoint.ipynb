# %%
from pywr.core import Model
from pywr.recorders import Recorder
from pywr.recorders._recorders import NodeRecorder
import pandas
import numpy as np
from pywr.notebook import draw_graph
from pywr.notebook import pywr_model_to_d3_json
from matplotlib import pyplot as plt

if __name__ == "__main__":

    m = Model.load("codegua.json")
    stats = m.run()
    print(stats)

    df = m.to_dataframe()
    print(df)
    df.plot(subplots=True, figsize = (12,6))
    plt.show()
    
    plt.figure()
    draw_graph(m, labels = True, attributes = True)
    plt.show()
# Out:
# Model executed 1 scenarios in 0.3 seconds, running at 4781.0 timesteps per second.
# Recorder   catchment4_flow catchment3_flow catchment2_flow catchment1_flow
#                          0               0               0               0
# 1990-01-01        0.000000        0.000000        0.000000        0.000000
# 1990-01-08        0.000000        0.000000        0.000000        0.000000
# 1990-01-15        0.000000        0.000000        0.000000        0.000000
# 1990-01-22        0.000000        0.000000        0.000000        0.000000
# 1990-01-29        0.000000        0.000000        0.000000        0.000000
# ...                    ...             ...             ...             ...
# 2018-12-03        2.775351        2.592522        2.380440        2.294990
# 2018-12-10        2.775351        2.592522        2.380440        2.294990
# 2018-12-17        2.775351        2.592522        2.380440        2.294990
# 2018-12-24        2.775351        2.592522        2.380440        2.294990
# 2018-12-31        2.370797        2.214619        2.033451        1.960456
#
# [1514 rows x 4 columns]
