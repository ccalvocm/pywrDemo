# %%
from pywr.core import Model
from pywr.recorders import Recorder
from pywr.recorders._recorders import NodeRecorder
import pandas
import numpy as np
from pywr.notebook import draw_graph
from pywr.notebook import pywr_model_to_d3_json
from matplotlib import pyplot as plt

if __name__ == "__main__":

    modelo="huasco.json"
    m = Model.load(modelo)
    stats = m.run()
    print(stats)

    df = m.to_dataframe()
    print(df)
    df.plot(subplots=True, figsize = (12,6))
    plt.show()
    
    plt.figure()
    draw_graph(m,labels = True, attributes = True)
    plt.show()
# Out:
# Model executed 1 scenarios in 0.7 seconds, running at 2140.5 timesteps per second.
# Recorder   inflow release1_flow SantaJuanaStorage
#                 0             0                 0
# 1993-04-01    4.0           0.0       169880000.0
# 1993-04-08    4.0           0.0       169880000.0
# 1993-04-15    4.0           0.0       169880000.0
# 1993-04-22    4.0           0.0       169880000.0
# 1993-04-29    4.0           0.0       169880000.0
# ...           ...           ...               ...
# 2022-03-03    4.0           0.0       169880000.0
# 2022-03-10    4.0           0.0       169880000.0
# 2022-03-17    4.0           0.0       169880000.0
# 2022-03-24    4.0           0.0       169880000.0
# 2022-03-31    4.0           0.0       169880000.0
#
# [1514 rows x 3 columns]
